# %%
import numpy as np

# %%
a =np.random.randn(3,3)

# %%
b = np.random.randn(3,1)

# %%
a + b
# Out:
# array([[-0.18931315, -0.04907317, -0.95912664],
#        [-0.15645291,  0.07426512, -1.35277661],
#        [ 0.89244253,  0.23074374, -0.93943004]])
